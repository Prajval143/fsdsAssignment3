# %% [markdown]
# 1. Functions reduce the need for duplicate code. This makes programs shorter, easier to read, and easier to update

# %% [markdown]
# 2.call

# %% [markdown]
# 3.Python creating functions. A function is created with the def keyword

# %% [markdown]
# 4.A function is a block of code that does a particular operation and returns a result. It usually accepts inputs as parameters and returns a result. The parameters are not mandatory. A function call is the code used to pass control to a function

# %% [markdown]
# 5.
# There's only one global Python scope per program execution.
# Every time you call a function, you create a new local scope.

# %% [markdown]
# 6.A local variable retains its value until the next time the function is called A local variable becomes undefined after the function call completes The local variable can be used outside the function any time after the function call completes

# %% [markdown]
# 7.In general, a function takes arguments (if any), performs some operations, and returns a value (or object). The value that a function returns to the caller is generally known as the function's return value. All Python functions have a return value, either explicit or implicit.

# %% [markdown]
# 8.If a function doesn't specify a return value, it returns None

# %% [markdown]
# 9. use global keyword before that

# %% [markdown]
# 10.None is a data type of its own (NoneType)

# %% [markdown]
# 11.That import statement imports a module named areallyourpetsnamederic.

# %% [markdown]
# 12.This function can be called with spam. bacon().

# %% [markdown]
# 13.Exception Handling

# %% [markdown]
# 14.The try block lets you test a block of code for errors. The except block lets you handle the error.
